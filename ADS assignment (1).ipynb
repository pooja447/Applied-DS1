# %%
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv('ukTrafficAADF.csv')  #read the data using pandas
df
# Out:
#         AADFYear     CP Estimation_method  \
# 0           2000   6007           Counted
# 1           2000   6009           Counted
# 2           2000   6035           Counted
# 3           2000   6054           Counted
# 4           2000   6055           Counted
# ...          ...    ...               ...
# 275380      2016  99736         Estimated
# 275381      2016  99756         Estimated
# 275382      2016  99941         Estimated
# 275383      2016  99942           Counted
# 275384      2016  99967         Estimated
#
#                                Estimation_method_detailed  \
# 0                                            Manual count
# 1                                            Manual count
# 2                                            Manual count
# 3                                            Manual count
# 4                                            Manual count
# ...                                                   ...
# ...

# %%
df2 = pd.read_csv('accidents_2005_to_2007.csv')  #read the data using pandas
df2
# Out:
# C:\Users\Hari\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (31) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       200501BS00001               525680.0                178240.0
# 1       200501BS00002               524170.0                181650.0
# 2       200501BS00003               524520.0                182240.0
# 3       200501BS00004               526900.0                177530.0
# 4       200501BS00005               528060.0                179040.0
# ...               ...                    ...                     ...
# 570006       2.01E+12               322650.0                566300.0
# 570007       2.01E+12               323710.0                566150.0
# 570008       2.01E+12               336900.0                586230.0
# ...

# %%
df2.columns
# Out:
# Index(['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR',
#        'Longitude', 'Latitude', 'Police_Force', 'Accident_Severity',
#        'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Day_of_Week',
#        'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)',
#        '1st_Road_Class', '1st_Road_Number', 'Road_Type', 'Speed_limit',
#        'Junction_Detail', 'Junction_Control', '2nd_Road_Class',
#        '2nd_Road_Number', 'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
#        'Weather_Conditions', 'Road_Surface_Conditions',
#        'Special_Conditions_at_Site', 'Carriageway_Hazards',
#        'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
#        'LSOA_of_Accident_Location', 'Year'],
#       dtype='object')

# %%
df3 = df2['Accident_Severity'].value_counts()   #number of accidents based on the severity wise
df3
# Out:
# 3    487161
# 2     74297
# 1      8553
# Name: Accident_Severity, dtype: int64

# %%
df1 = acc_rec_yrly['Accident_Severity'].value_counts()   
''
df1
# Out:
# Year  Accident_Severity
# 2005  3                    170793
#       2                     25029
#       1                      2913
# 2006  3                    161289
#       2                     24946
#       1                      2926
# 2007  3                    155079
#       2                     24322
#       1                      2714
# Name: Accident_Severity, dtype: int64

# %%
df4 = df2['Road_Type'].value_counts()   # number of accidents on different roads
df4
# Out:
# Single carriageway    423414
# Dual carriageway       87274
# Roundabout             36637
# One way street         12434
# Slip road               5936
# Unknown                 4316
# Name: Road_Type, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data visualization using pie chart
# pie chart shows numbers of accidents which are occured n different road types.
# on the single carriiageway road type maximum number of accidents were occured.
df4.plot(kind = 'pie')
plt.title('Number of accidents on different Road types')
plt.legend()
plt.show()

# %%
#data visualization using bar graph
#bar graph shows the accident severity year wise. 
#most of the accidents occured on the third severity in the three years.

df1.unstack().plot(kind = 'bar') # unstack is a function that pivots the level of the indexed columns in a stacked manner.
plt.title('Accident Severity Year Wise')
plt.xlabel('Year')
plt.ylabel('count')
plt.legend()
plt.show()
